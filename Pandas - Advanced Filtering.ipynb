# %%
import pandas as pd

# %%
summer = pd.read_csv("C:\\Users\\subha\\Course_Materials_Part1\\Course_Materials_Part1\\Video_Lecture_NBs\\summer.csv")

# %%
summer.head()
# Out:
#    Year    City     Sport Discipline             Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios     GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis     GRE    Men
# 4  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon     GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver

# %%
og_1988 = summer.loc[summer.Year == 1988]

# %%
og_1988.head()
# Out:
#        Year   City     Sport Discipline                      Athlete Country  \
# 18051  1988  Seoul  Aquatics     Diving           MENA CAMPOS, Jesus     MEX
# 18052  1988  Seoul  Aquatics     Diving            LOUGANIS, Gregory     USA
# 18053  1988  Seoul  Aquatics     Diving                    XIONG, Ni     CHN
# 18054  1988  Seoul  Aquatics     Diving  WYLAND-WILLIAMS, Wendy Lian     USA
# 18055  1988  Seoul  Aquatics     Diving                  XU, Yan-Mei     CHN
#
#       Gender         Event   Medal
# 18051    Men  10M Platform  Bronze
# 18052    Men  10M Platform    Gold
# 18053    Men  10M Platform  Silver
# 18054  Women  10M Platform  Bronze
# 18055  Women  10M Platform    Gold

# %%
og_1988.tail()
# Out:
#        Year   City      Sport       Discipline                   Athlete  \
# 19592  1988  Seoul  Wrestling  Wrestling Gre-R    KOMCHEV, Atanas Slavov
# 19593  1988  Seoul  Wrestling  Wrestling Gre-R     KOSKELA, Harri Matias
# 19594  1988  Seoul  Wrestling  Wrestling Gre-R  KOSLOWSKI, Dennis Marvin
# 19595  1988  Seoul  Wrestling  Wrestling Gre-R          WRONSKI, Andrzej
# 19596  1988  Seoul  Wrestling  Wrestling Gre-R           HIMMEL, Gerhard
#
#       Country Gender                          Event   Medal
# 19592     BUL    Men  82 - 90KG (Light-Heavyweight)    Gold
# 19593     FIN    Men  82 - 90KG (Light-Heavyweight)  Silver
# 19594     USA    Men       90 - 100KG (Heavyweight)  Bronze
# 19595     POL    Men       90 - 100KG (Heavyweight)    Gold
# 19596     FRG    Men       90 - 100KG (Heavyweight)  Silver

# %%
og_1988.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1546 entries, 18051 to 19596
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Year        1546 non-null   int64
#  1   City        1546 non-null   object
#  2   Sport       1546 non-null   object
#  3   Discipline  1546 non-null   object
#  4   Athlete     1546 non-null   object
#  5   Country     1546 non-null   object
#  6   Gender      1546 non-null   object
#  7   Event       1546 non-null   object
#  8   Medal       1546 non-null   object
# dtypes: int64(1), object(8)
# memory usage: 120.8+ KB

# %%
og_since1992 = summer.loc[summer.Year >= 1992]

# %%
og_since1992.head()
# Out:
#        Year       City     Sport Discipline            Athlete Country Gender  \
# 19597  1992  Barcelona  Aquatics     Diving          XIONG, Ni     CHN    Men
# 19598  1992  Barcelona  Aquatics     Diving        SUN, Shuwei     CHN    Men
# 19599  1992  Barcelona  Aquatics     Diving    DONIE, Scott R.     USA    Men
# 19600  1992  Barcelona  Aquatics     Diving  CLARK, Mary Ellen     USA  Women
# 19601  1992  Barcelona  Aquatics     Diving        FU, Mingxia     CHN  Women
#
#               Event   Medal
# 19597  10M Platform  Bronze
# 19598  10M Platform    Gold
# 19599  10M Platform  Silver
# 19600  10M Platform  Bronze
# 19601  10M Platform    Gold

# %%
og_since1992.tail()
# Out:
#        Year    City      Sport           Discipline  \
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender     Event   Medal
# 31160         JANIKOWSKI, Damian     POL    Men  Wg 84 KG  Bronze
# 31161  REZAEI, Ghasem Gholamreza     IRI    Men  Wg 96 KG    Gold
# 31162             TOTROV, Rustam     RUS    Men  Wg 96 KG  Silver
# 31163          ALEKSANYAN, Artur     ARM    Men  Wg 96 KG  Bronze
# 31164             LIDBERG, Jimmy     SWE    Men  Wg 96 KG  Bronze

# %%
summer.Year.between(1960,1969).head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: Year, dtype: bool

# %%
og_60s = summer.loc[summer.Year.between(1960,1969)]

# %%
og_60s.head()
# Out:
#       Year  City     Sport Discipline                      Athlete Country  \
# 9792  1960  Rome  Aquatics     Diving           PHELPS, Brian Eric     GBR
# 9793  1960  Rome  Aquatics     Diving        WEBSTER, Robert David     USA
# 9794  1960  Rome  Aquatics     Diving         TOBIAN, Gary Milburn     USA
# 9795  1960  Rome  Aquatics     Diving               KRUTOVA, Ninel     URS
# 9796  1960  Rome  Aquatics     Diving  KRÄMER-ENGEL-GULBIN, Ingrid     EUA
#
#      Gender         Event   Medal
# 9792    Men  10M Platform  Bronze
# 9793    Men  10M Platform    Gold
# 9794    Men  10M Platform  Silver
# 9795  Women  10M Platform  Bronze
# 9796  Women  10M Platform    Gold

# %%
og_60s.tail()
# Out:
#        Year    City      Sport       Discipline                   Athlete  \
# 12710  1968  Mexico  Wrestling  Wrestling Gre-R              METZ, Lothar
# 12711  1968  Mexico  Wrestling  Wrestling Gre-R         OLEINIK, Valentin
# 12712  1968  Mexico  Wrestling  Wrestling Gre-R       MARTINESCU, Nicolae
# 12713  1968  Mexico  Wrestling  Wrestling Gre-R  RADEV, Boyan Aleksandrov
# 12714  1968  Mexico  Wrestling  Wrestling Gre-R        YAKOVENKO, Nikolai
#
#       Country Gender                          Event   Medal
# 12710     GDR    Men       78 - 87KG (Middleweight)    Gold
# 12711     URS    Men       78 - 87KG (Middleweight)  Silver
# 12712     ROU    Men  87 - 97KG (Light-Heavyweight)  Bronze
# 12713     BUL    Men  87 - 97KG (Light-Heavyweight)    Gold
# 12714     URS    Men  87 - 97KG (Light-Heavyweight)  Silver

# %%
my_fav_games = [1972,1996]

# %%
summer.Year.isin(my_fav_games).head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: Year, dtype: bool

# %%
og_72_96 = summer.loc[summer.Year.isin(my_fav_games)]

# %%
og_72_96.head()
# Out:
#        Year    City     Sport Discipline                   Athlete Country  \
# 12715  1972  Munich  Aquatics     Diving  CAGNOTTO, Giorgio Franco     ITA
# 12716  1972  Munich  Aquatics     Diving            DIBIASI, Klaus     ITA
# 12717  1972  Munich  Aquatics     Diving    RYDZE, Richard Anthony     USA
# 12718  1972  Munich  Aquatics     Diving           JANICKE, Marina     GDR
# 12719  1972  Munich  Aquatics     Diving   KNAPE-LINDBERGH, Ulrika     SWE
#
#       Gender         Event   Medal
# 12715    Men  10M Platform  Bronze
# 12716    Men  10M Platform    Gold
# 12717    Men  10M Platform  Silver
# 12718  Women  10M Platform  Bronze
# 12719  Women  10M Platform    Gold

# %%
og_not_72_96 =  summer.loc[~summer.Year.isin(my_fav_games)]

# %%
og_not_72_96.head()
# Out:
#    Year    City     Sport Discipline             Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios     GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis     GRE    Men
# 4  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon     GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver

# %%
titanic = pd.read_csv("C:\\Users\\subha\\Course_Materials_Part1\\Course_Materials_Part1\\Video_Lecture_NBs\\titanic.csv")

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
titanic.sex == 'male'
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888    False
# 889     True
# 890     True
# Name: sex, Length: 891, dtype: bool

# %%
(titanic.sex == 'male').any()
# Out:
# True

# %%
(titanic.sex == 'male').all()
# Out:
# False

# %%
(titanic.age==80).any()
# Out:
# True

# %%
pd.Series([-1,0.5,1.-0.1,0]).all()
#some value is 0
# Out:
# False

# %%
pd.Series([-1,0.5,1.-0.1,0]).any()
#any value is 0
# Out:
# True

# %%
titanic.fare.all()
# Out:
# False

# %%
summer.head()
# Out:
#    Year    City     Sport Discipline             Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios     GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis     GRE    Men
# 4  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon     GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver

# %%
summer.drop(columns = 'Sport')
# Out:
#        Year    City           Discipline                    Athlete Country  \
# 0      1896  Athens             Swimming              HAJOS, Alfred     HUN
# 1      1896  Athens             Swimming           HERSCHMANN, Otto     AUT
# 2      1896  Athens             Swimming          DRIVAS, Dimitrios     GRE
# 3      1896  Athens             Swimming         MALOKINIS, Ioannis     GRE
# 4      1896  Athens             Swimming         CHASAPIS, Spiridon     GRE
# ...     ...     ...                  ...                        ...     ...
# 31160  2012  London  Wrestling Freestyle         JANIKOWSKI, Damian     POL
# 31161  2012  London  Wrestling Freestyle  REZAEI, Ghasem Gholamreza     IRI
# 31162  2012  London  Wrestling Freestyle             TOTROV, Rustam     RUS
# 31163  2012  London  Wrestling Freestyle          ALEKSANYAN, Artur     ARM
# 31164  2012  London  Wrestling Freestyle             LIDBERG, Jimmy     SWE
#
#       Gender                       Event   Medal
# ...

# %%
summer.drop(columns = ['Sport', 'Discipline'])
# Out:
#        Year    City                    Athlete Country Gender  \
# 0      1896  Athens              HAJOS, Alfred     HUN    Men
# 1      1896  Athens           HERSCHMANN, Otto     AUT    Men
# 2      1896  Athens          DRIVAS, Dimitrios     GRE    Men
# 3      1896  Athens         MALOKINIS, Ioannis     GRE    Men
# 4      1896  Athens         CHASAPIS, Spiridon     GRE    Men
# ...     ...     ...                        ...     ...    ...
# 31160  2012  London         JANIKOWSKI, Damian     POL    Men
# 31161  2012  London  REZAEI, Ghasem Gholamreza     IRI    Men
# 31162  2012  London             TOTROV, Rustam     RUS    Men
# 31163  2012  London          ALEKSANYAN, Artur     ARM    Men
# 31164  2012  London             LIDBERG, Jimmy     SWE    Men
#
#                             Event   Medal
# 0                  100M Freestyle    Gold
# 1                  100M Freestyle  Silver
# 2      100M Freestyle For Sailors  Bronze
# 3      100M Freestyle For Sailors    Gold
# ...

# %%
summer.drop(labels ='Event', axis =1)
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender   Medal
# 0                  HAJOS, Alfred     HUN    Men    Gold
# 1               HERSCHMANN, Otto     AUT    Men  Silver
# 2              DRIVAS, Dimitrios     GRE    Men  Bronze
# 3             MALOKINIS, Ioannis     GRE    Men    Gold
# ...

# %%
del summer['Event']

# %%
summer.head()
# Out:
#    Year    City     Sport Discipline             Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios     GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis     GRE    Men
# 4  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon     GRE    Men
#
#     Medal
# 0    Gold
# 1  Silver
# 2  Bronze
# 3    Gold
# 4  Silver

# %%
summer = summer.loc[:,['Year','City','Athlete','Country','Gender','Medal']]

# %%
summer.head()
# Out:
#    Year    City             Athlete Country Gender   Medal
# 0  1896  Athens       HAJOS, Alfred     HUN    Men    Gold
# 1  1896  Athens    HERSCHMANN, Otto     AUT    Men  Silver
# 2  1896  Athens   DRIVAS, Dimitrios     GRE    Men  Bronze
# 3  1896  Athens  MALOKINIS, Ioannis     GRE    Men    Gold
# 4  1896  Athens  CHASAPIS, Spiridon     GRE    Men  Silver

# %%
summer = pd.read_csv("C:\\Users\\subha\\Course_Materials_Part1\\Course_Materials_Part1\\Video_Lecture_NBs\\summer.csv",index_col = 'Athlete')

# %%
summer.head()
# Out:
#                     Year    City     Sport Discipline Country Gender  \
# Athlete
# HAJOS, Alfred       1896  Athens  Aquatics   Swimming     HUN    Men
# HERSCHMANN, Otto    1896  Athens  Aquatics   Swimming     AUT    Men
# DRIVAS, Dimitrios   1896  Athens  Aquatics   Swimming     GRE    Men
# MALOKINIS, Ioannis  1896  Athens  Aquatics   Swimming     GRE    Men
# CHASAPIS, Spiridon  1896  Athens  Aquatics   Swimming     GRE    Men
#
#                                          Event   Medal
# Athlete
# HAJOS, Alfred                   100M Freestyle    Gold
# HERSCHMANN, Otto                100M Freestyle  Silver
# DRIVAS, Dimitrios   100M Freestyle For Sailors  Bronze
# MALOKINIS, Ioannis  100M Freestyle For Sailors    Gold
# CHASAPIS, Spiridon  100M Freestyle For Sailors  Silver

# %%
summer.drop(index=['HAJOS, Alfred'],inplace = True)

# %%
summer.head()
# Out:
#                        Year    City     Sport Discipline Country Gender  \
# Athlete
# HERSCHMANN, Otto       1896  Athens  Aquatics   Swimming     AUT    Men
# DRIVAS, Dimitrios      1896  Athens  Aquatics   Swimming     GRE    Men
# MALOKINIS, Ioannis     1896  Athens  Aquatics   Swimming     GRE    Men
# CHASAPIS, Spiridon     1896  Athens  Aquatics   Swimming     GRE    Men
# CHOROPHAS, Efstathios  1896  Athens  Aquatics   Swimming     GRE    Men
#
#                                             Event   Medal
# Athlete
# HERSCHMANN, Otto                   100M Freestyle  Silver
# DRIVAS, Dimitrios      100M Freestyle For Sailors  Bronze
# MALOKINIS, Ioannis     100M Freestyle For Sailors    Gold
# CHASAPIS, Spiridon     100M Freestyle For Sailors  Silver
# CHOROPHAS, Efstathios             1200M Freestyle  Bronze

# %%
summer.drop(labels = 'DRIVAS, Dimitrios', axis =0, inplace=True)

# %%
summer.head()
# Out:
#                        Year    City     Sport Discipline Country Gender  \
# Athlete
# HERSCHMANN, Otto       1896  Athens  Aquatics   Swimming     AUT    Men
# MALOKINIS, Ioannis     1896  Athens  Aquatics   Swimming     GRE    Men
# CHASAPIS, Spiridon     1896  Athens  Aquatics   Swimming     GRE    Men
# CHOROPHAS, Efstathios  1896  Athens  Aquatics   Swimming     GRE    Men
# ANDREOU, Joannis       1896  Athens  Aquatics   Swimming     GRE    Men
#
#                                             Event   Medal
# Athlete
# HERSCHMANN, Otto                   100M Freestyle  Silver
# MALOKINIS, Ioannis     100M Freestyle For Sailors    Gold
# CHASAPIS, Spiridon     100M Freestyle For Sailors  Silver
# CHOROPHAS, Efstathios             1200M Freestyle  Bronze
# ANDREOU, Joannis                  1200M Freestyle  Silver

# %%
summer = summer.loc[summer.Year == 1996]

# %%
summer.head()
# Out:
#                    Year     City     Sport Discipline Country Gender  \
# Athlete
# XIAO, Hailiang     1996  Atlanta  Aquatics     Diving     CHN    Men
# SAUTIN, Dmitry     1996  Atlanta  Aquatics     Diving     RUS    Men
# HEMPEL, Jan        1996  Atlanta  Aquatics     Diving     GER    Men
# CLARK, Mary Ellen  1996  Atlanta  Aquatics     Diving     USA  Women
# FU, Mingxia        1996  Atlanta  Aquatics     Diving     CHN  Women
#
#                           Event   Medal
# Athlete
# XIAO, Hailiang     10M Platform  Bronze
# SAUTIN, Dmitry     10M Platform    Gold
# HEMPEL, Jan        10M Platform  Silver
# CLARK, Mary Ellen  10M Platform  Bronze
# FU, Mingxia        10M Platform    Gold

# %%
summer = pd.read_csv("C:\\Users\\subha\\Course_Materials_Part1\\Course_Materials_Part1\\Video_Lecture_NBs\\summer.csv",index_col = 'Athlete')

# %%
summer.head()
# Out:
#                     Year    City     Sport Discipline Country Gender  \
# Athlete
# HAJOS, Alfred       1896  Athens  Aquatics   Swimming     HUN    Men
# HERSCHMANN, Otto    1896  Athens  Aquatics   Swimming     AUT    Men
# DRIVAS, Dimitrios   1896  Athens  Aquatics   Swimming     GRE    Men
# MALOKINIS, Ioannis  1896  Athens  Aquatics   Swimming     GRE    Men
# CHASAPIS, Spiridon  1896  Athens  Aquatics   Swimming     GRE    Men
#
#                                          Event   Medal
# Athlete
# HAJOS, Alfred                   100M Freestyle    Gold
# HERSCHMANN, Otto                100M Freestyle  Silver
# DRIVAS, Dimitrios   100M Freestyle For Sailors  Bronze
# MALOKINIS, Ioannis  100M Freestyle For Sailors    Gold
# CHASAPIS, Spiridon  100M Freestyle For Sailors  Silver

# %%
mask1 = summer.Year ==1996
mask2 = summer.Sport == 'Aquatics'

# %%
summer = summer.loc[~(mask1|mask2)]

# %%
summer.head()
# Out:
#                   Year    City      Sport Discipline Country Gender  \
# Athlete
# LANE, Francis     1896  Athens  Athletics  Athletics     USA    Men
# SZOKOLYI, Alajos  1896  Athens  Athletics  Athletics     HUN    Men
# BURKE, Thomas     1896  Athens  Athletics  Athletics     USA    Men
# HOFMANN, Fritz    1896  Athens  Athletics  Athletics     GER    Men
# CURTIS, Thomas    1896  Athens  Athletics  Athletics     USA    Men
#
#                          Event   Medal
# Athlete
# LANE, Francis             100M  Bronze
# SZOKOLYI, Alajos          100M  Bronze
# BURKE, Thomas             100M    Gold
# HOFMANN, Fritz            100M  Silver
# CURTIS, Thomas    110M Hurdles    Gold

# %%
(summer.Year ==1996).value_counts()
# Out:
# False    25398
# Name: Year, dtype: int64

# %%
1996 in summer.Year.values
# Out:
# False

# %%
summer.Sport.isin(['Aquatics']).any()
# Out:
# False

# %%
(summer.Sport=='Aquatics').any()
# Out:
# False

# %%
titanic = pd.read_csv("C:\\Users\\subha\\Course_Materials_Part1\\Course_Materials_Part1\\Video_Lecture_NBs\\titanic.csv")

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
titanic["Zeros"]=0

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck  Zeros
# 0         0       3    male  22.0      1      0   7.2500        S  NaN      0
# 1         1       1  female  38.0      1      0  71.2833        C    C      0
# 2         1       3  female  26.0      0      0   7.9250        S  NaN      0
# 3         1       1  female  35.0      1      0  53.1000        S    C      0
# 4         0       3    male  35.0      0      0   8.0500        S  NaN      0

# %%
titanic.Ones = 1

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck  Zeros
# 0         0       3    male  22.0      1      0   7.2500        S  NaN      0
# 1         1       1  female  38.0      1      0  71.2833        C    C      0
# 2         1       3  female  26.0      0      0   7.9250        S  NaN      0
# 3         1       1  female  35.0      1      0  53.1000        S    C      0
# 4         0       3    male  35.0      0      0   8.0500        S  NaN      0

# %%
titanic.Ones
# Out:
# 1

# %%
1912 - titanic.age
# Out:
# 0      1890.0
# 1      1874.0
# 2      1886.0
# 3      1877.0
# 4      1877.0
#         ...
# 886    1885.0
# 887    1893.0
# 888       NaN
# 889    1886.0
# 890    1880.0
# Name: age, Length: 891, dtype: float64

# %%
titanic['YoB'] = 1912 - titanic.age

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck  Zeros  \
# 0         0       3    male  22.0      1      0   7.2500        S  NaN      0
# 1         1       1  female  38.0      1      0  71.2833        C    C      0
# 2         1       3  female  26.0      0      0   7.9250        S  NaN      0
# 3         1       1  female  35.0      1      0  53.1000        S    C      0
# 4         0       3    male  35.0      0      0   8.0500        S  NaN      0
#
#       YoB
# 0  1890.0
# 1  1874.0
# 2  1886.0
# 3  1877.0
# 4  1877.0

# %%
titanic ['relatives'] = titanic.sibsp+titanic.parch

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck  Zeros  \
# 0         0       3    male  22.0      1      0   7.2500        S  NaN      0
# 1         1       1  female  38.0      1      0  71.2833        C    C      0
# 2         1       3  female  26.0      0      0   7.9250        S  NaN      0
# 3         1       1  female  35.0      1      0  53.1000        S    C      0
# 4         0       3    male  35.0      0      0   8.0500        S  NaN      0
#
#       YoB  relatives
# 0  1890.0          1
# 1  1874.0          1
# 2  1886.0          0
# 3  1877.0          1
# 4  1877.0          0

# %%
titanic.drop(columns = ['sibsp','parch'],inplace=True)

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age     fare embarked deck  Zeros     YoB  \
# 0         0       3    male  22.0   7.2500        S  NaN      0  1890.0
# 1         1       1  female  38.0  71.2833        C    C      0  1874.0
# 2         1       3  female  26.0   7.9250        S  NaN      0  1886.0
# 3         1       1  female  35.0  53.1000        S    C      0  1877.0
# 4         0       3    male  35.0   8.0500        S  NaN      0  1877.0
#
#    relatives
# 0          1
# 1          1
# 2          0
# 3          1
# 4          0

# %%
titanic.drop(columns = ['inflated_fare'],inplace=True)

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age        fare embarked deck  Zeros     YoB  \
# 0         0       3    male  22.0   96.497500        S  NaN      0  1890.0
# 1         1       1  female  38.0  948.780723        C    C      0  1874.0
# 2         1       3  female  26.0  105.481750        S  NaN      0  1886.0
# 3         1       1  female  35.0  706.761000        S    C      0  1877.0
# 4         0       3    male  35.0  107.145500        S  NaN      0  1877.0
#
#    relatives
# 0          1
# 1          1
# 2          0
# 3          1
# 4          0

# %%
titanic.fare = titanic.fare*10

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age        fare embarked deck  Zeros     YoB  \
# 0         0       3    male  22.0   964.97500        S  NaN      0  1890.0
# 1         1       1  female  38.0  9487.80723        C    C      0  1874.0
# 2         1       3  female  26.0  1054.81750        S  NaN      0  1886.0
# 3         1       1  female  35.0  7067.61000        S    C      0  1877.0
# 4         0       3    male  35.0  1071.45500        S  NaN      0  1877.0
#
#    relatives
# 0          1
# 1          1
# 2          0
# 3          1
# 4          0

# %%
titanic = pd.read_csv("C:\\Users\\subha\\Course_Materials_Part1\\Course_Materials_Part1\\Video_Lecture_NBs\\titanic.csv")

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
relatives = titanic.sibsp+titanic.parch
relatives.head()
# Out:
# 0    1
# 1    1
# 2    0
# 3    1
# 4    0
# dtype: int64

# %%
titanic.insert(loc=6,column='relatives', value = relatives)

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch  relatives     fare embarked  \
# 0         0       3    male  22.0      1      0          1   7.2500        S
# 1         1       1  female  38.0      1      0          1  71.2833        C
# 2         1       3  female  26.0      0      0          0   7.9250        S
# 3         1       1  female  35.0      1      0          1  53.1000        S
# 4         0       3    male  35.0      0      0          0   8.0500        S
#
#   deck
# 0  NaN
# 1    C
# 2  NaN
# 3    C
# 4  NaN
