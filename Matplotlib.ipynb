# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:\\Users\\subha\\Statistics+Using+Python+All+Resources\\Datasets\\Piece_Dim.csv")

# %%
df.head()
# Out:
#   Item_No  Length  Width  Height Operator
# 0  Item-1  102.67  49.53   19.69     Op-1
# 1  Item-2  102.50  51.42   19.63     Op-1
# 2  Item-3   95.37  52.25   21.51     Op-1
# 3  Item-4   94.77  49.24   18.60     Op-1
# 4  Item-5  104.26  47.90   19.46     Op-1

# %%
df.describe()
# Out:
#            Length      Width     Height
# count   50.000000  50.000000  50.000000
# mean   100.128800  49.461400  20.014000
# std      5.075593   2.615639   1.074069
# min     89.820000  44.460000  17.370000
# 25%     95.675000  48.105000  19.375000
# 50%     99.830000  49.315000  19.930000
# 75%    104.402500  50.780000  20.595000
# max    110.540000  55.760000  23.110000

# %%
plt.hist(df['Length'])
# Out:
# (array([2., 3., 9., 6., 6., 7., 4., 6., 5., 2.]),
#  array([ 89.82 ,  91.892,  93.964,  96.036,  98.108, 100.18 , 102.252,
#         104.324, 106.396, 108.468, 110.54 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['Length'])
plt.show()

# %%
plt.hist(df['Length'],bins=15,color='red')
plt.xlabel('Length in mm')
plt.ylabel('Count')
plt.title('Histogram of Piece Length')
plt.show()

# %%
plt.boxplot(df['Length'])
plt.show()

# %%
op1 = df[df['Operator']=='Op-1']
op2 = df[df['Operator']=='Op-2']

# %%
plt.boxplot([op1['Length'],op2['Length']])
plt.xlabel('Operator')
plt.ylabel('Length')
plt.title('Box Plot by Operators')
plt.show()

# %%
plt.boxplot([op1['Length'],op2['Length']],notch=True)
plt.xlabel('Operator')
plt.ylabel('Length')
plt.title('Box Plot by Operators')
plt.show()

# %%
plt.plot(df['Length'])
plt.show()

# %%
plt.plot(df['Length'])
mean_1 = df['Length'].mean()
sd_1 = df['Length'].std()
plt.axhline(y=mean_1,color='red',linestyle='-')
plt.axhline(y=(mean_1+3*sd_1),color='red',linestyle='--')
plt.axhline(y=(mean_1-3*sd_1),color='red',linestyle='--')
plt.show()

# %%
plt.scatter(df['Length'],df['Width'],marker="D")
plt.show()

# %%
plt.scatter(df['Length'],df['Width'],marker="D")
plt.show()

# %%
opers = ['Operator1','Operator2','Operator3']
pieces = [50,35,70]
plt.bar(opers,pieces)
plt.show()

# %%
low=df[df['Length']<95]['Length'].count()

# %%
low
# Out:
# 7

# %%
low=df[df['Length']<95]['Length'].count()
med = df[(df['Length']>=95)&(df['Length']<=105)]['Length'].count()
high=df[df['Length']>105]['Length'].count()

# %%
size1 = [low,med,high]
group1 = ['<95','b/w 95 and 105','>105']

# %%
plt.bar(group1,size1)
plt.show()

# %%
plt.bar(group1,size1)
plt.savefig('MyBoxPlot.png')

# %%
pwd
# Out:
# 'C:\\Users\\subha\\Statistics+Using+Python+All+Resources\\Practice Exercises'
