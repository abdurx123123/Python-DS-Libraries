# %%
import pandas as pd

# %%
titanic = pd.read_csv("C:\\Users\\subha\\Course_Materials_Part1\\Course_Materials_Part1\\Video_Lecture_NBs\\titanic.csv")

# %%
titanic.head(10)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN
# 5         0       3    male   NaN      0      0   8.4583        Q  NaN
# 6         0       1    male  54.0      0      0  51.8625        S    E
# 7         0       3    male   2.0      3      1  21.0750        S  NaN
# 8         1       3  female  27.0      0      2  11.1333        S  NaN
# 9         1       2  female  14.0      1      0  30.0708        C  NaN

# %%
titanic.sex.head(10)
# Out:
# 0      male
# 1    female
# 2    female
# 3    female
# 4      male
# 5      male
# 6      male
# 7      male
# 8    female
# 9    female
# Name: sex, dtype: object

# %%
titanic.sex == 'male'
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888    False
# 889     True
# 890     True
# Name: sex, Length: 891, dtype: bool

# %%
titanic[titanic.sex == 'male']
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked deck
# 0           0       3  male  22.0      1      0   7.2500        S  NaN
# 4           0       3  male  35.0      0      0   8.0500        S  NaN
# 5           0       3  male   NaN      0      0   8.4583        Q  NaN
# 6           0       1  male  54.0      0      0  51.8625        S    E
# 7           0       3  male   2.0      3      1  21.0750        S  NaN
# ..        ...     ...   ...   ...    ...    ...      ...      ...  ...
# 883         0       2  male  28.0      0      0  10.5000        S  NaN
# 884         0       3  male  25.0      0      0   7.0500        S  NaN
# 886         0       2  male  27.0      0      0  13.0000        S  NaN
# 889         1       1  male  26.0      0      0  30.0000        C    C
# 890         0       3  male  32.0      0      0   7.7500        Q  NaN
#
# [577 rows x 9 columns]

# %%
titanic.loc[titanic.sex == 'male', 'fare']
# Out:
# 0       7.2500
# 4       8.0500
# 5       8.4583
# 6      51.8625
# 7      21.0750
#         ...
# 883    10.5000
# 884     7.0500
# 886    13.0000
# 889    30.0000
# 890     7.7500
# Name: fare, Length: 577, dtype: float64

# %%
titanic.dtypes
# Out:
# survived      int64
# pclass        int64
# sex          object
# age         float64
# sibsp         int64
# parch         int64
# fare        float64
# embarked     object
# deck         object
# dtype: object

# %%
mask_2 = titanic.dtypes == object
mask_2
# Out:
# survived    False
# pclass      False
# sex          True
# age         False
# sibsp       False
# parch       False
# fare        False
# embarked     True
# deck         True
# dtype: bool

# %%
titanic.loc[:, ~mask_2]
# Out:
#      survived  pclass   age  sibsp  parch     fare
# 0           0       3  22.0      1      0   7.2500
# 1           1       1  38.0      1      0  71.2833
# 2           1       3  26.0      0      0   7.9250
# 3           1       1  35.0      1      0  53.1000
# 4           0       3  35.0      0      0   8.0500
# ..        ...     ...   ...    ...    ...      ...
# 886         0       2  27.0      0      0  13.0000
# 887         1       1  19.0      0      0  30.0000
# 888         0       3   NaN      1      2  23.4500
# 889         1       1  26.0      0      0  30.0000
# 890         0       3  32.0      0      0   7.7500
#
# [891 rows x 6 columns]

# %%
mask_1 = titanic.sex == 'male'
mask_1
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888    False
# 889     True
# 890     True
# Name: sex, Length: 891, dtype: bool

# %%
titanic.loc[mask_1, ~mask_2]
# Out:
#      survived  pclass   age  sibsp  parch     fare
# 0           0       3  22.0      1      0   7.2500
# 4           0       3  35.0      0      0   8.0500
# 5           0       3   NaN      0      0   8.4583
# 6           0       1  54.0      0      0  51.8625
# 7           0       3   2.0      3      1  21.0750
# ..        ...     ...   ...    ...    ...      ...
# 883         0       2  28.0      0      0  10.5000
# 884         0       3  25.0      0      0   7.0500
# 886         0       2  27.0      0      0  13.0000
# 889         1       1  26.0      0      0  30.0000
# 890         0       3  32.0      0      0   7.7500
#
# [577 rows x 6 columns]

# %%
mask3 = titanic.age >14
mask3
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 886     True
# 887     True
# 888    False
# 889     True
# 890     True
# Name: age, Length: 891, dtype: bool

# %%
(mask_1 & mask3).head()
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4     True
# dtype: bool

# %%
male_surv = titanic.loc[mask_1&mask3, ['survived','pclass','sex','age']]
male_surv.head()
# Out:
#     survived  pclass   sex   age
# 0          0       3  male  22.0
# 4          0       3  male  35.0
# 6          0       1  male  54.0
# 12         0       3  male  20.0
# 13         0       3  male  39.0

# %%
male_surv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 414 entries, 0 to 890
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  414 non-null    int64
#  1   pclass    414 non-null    int64
#  2   sex       414 non-null    object
#  3   age       414 non-null    float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 16.2+ KB

# %%
male_surv.describe()
# Out:
#          survived      pclass         age
# count  414.000000  414.000000  414.000000
# mean     0.173913    2.309179   33.129227
# std      0.379493    0.829868   12.922177
# min      0.000000    1.000000   15.000000
# 25%      0.000000    2.000000   23.000000
# 50%      0.000000    3.000000   30.000000
# 75%      0.000000    3.000000   40.000000
# max      1.000000    3.000000   80.000000

# %%
mask_4 = titanic.sex =='female'
mask_4
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 886    False
# 887     True
# 888     True
# 889    False
# 890    False
# Name: sex, Length: 891, dtype: bool

# %%
mask_5 = titanic.age < 14
mask_5
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: age, Length: 891, dtype: bool

# %%
(mask_4 | mask_5).head()
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# 4    False
# dtype: bool

# %%
won_or_chi = titanic.loc[mask_4|mask_5, ['survived','pclass','sex','age']]

# %%
won_or_chi
# Out:
#      survived  pclass     sex   age
# 1           1       1  female  38.0
# 2           1       3  female  26.0
# 3           1       1  female  35.0
# 7           0       3    male   2.0
# 8           1       3  female  27.0
# ..        ...     ...     ...   ...
# 880         1       2  female  25.0
# 882         0       3  female  22.0
# 885         0       3  female  39.0
# 887         1       1  female  19.0
# 888         0       3  female   NaN
#
# [351 rows x 4 columns]

# %%
won_or_chi.head()
# Out:
#    survived  pclass     sex   age
# 1         1       1  female  38.0
# 2         1       3  female  26.0
# 3         1       1  female  35.0
# 7         0       3    male   2.0
# 8         1       3  female  27.0

# %%
won_or_chi.describe()
# Out:
#          survived      pclass         age
# count  351.000000  351.000000  298.000000
# mean     0.723647    2.205128   25.039161
# std      0.447832    0.847232   15.314631
# min      0.000000    1.000000    0.420000
# 25%      0.000000    1.000000   14.125000
# 50%      1.000000    2.000000   24.000000
# 75%      1.000000    3.000000   35.000000
# max      1.000000    3.000000   63.000000
